# %%
# !pip install pymongo
# Out:
# Requirement already satisfied: pymongo in /Users/kelly/opt/anaconda3/lib/python3.9/site-packages (4.0.1)

# %%
import pymongo
import pandas as pd
import json

# %%
client = pymongo.MongoClient("mongodb://localhost:27017")

# %%
df = pd.read_csv("netflix.csv")
df
# Out:
#                        title rating  \
# 0               White Chicks  PG-13
# 1        Lucky Number Slevin      R
# 2             Grey's Anatomy  TV-14
# 3               Prison Break  TV-14
# 4      How I Met Your Mother  TV-PG
# ..                       ...    ...
# 995                  The BFG     PG
# 996  The Secret Life of Pets     PG
# 997         Precious Puppies   TV-G
# 998              Beary Tales   TV-G
# 999          Growing Up Wild      G
#
#                                            ratingLevel  ratingDescription  \
# 0    crude and sexual humor, language and some drug...                 80
# 1    strong violence, sexual content and adult lang...                100
# 2    Parents strongly cautioned. May be unsuitable ...                 90
# 3    Parents strongly cautioned. May be unsuitable ...                 90
# 4    Parental guidance suggested. May not be suitab...                 70
# ..                                                 ...                ...
# 995  for action/peril, some scary moments and brief...                 60
# 996                     for action and some rude humor                 60
# 997                             Suitable for all ages.                 35
# 998                             Suitable for all ages.                 35
# 999                                                NaN                 35
#
#      release year  user rating score  user rating size
# 0            2004               82.0                80
# 1            2006                NaN                82
# 2            2016               98.0                80
# 3            2008               98.0                80
# 4            2014               94.0                80
# ..            ...                ...               ...
# 995          2016               97.0                80
# 996          2016                NaN                81
# 997          2003                NaN                82
# 998          2013                NaN                82
# 999          2016               80.0                80
#
# [1000 rows x 7 columns]

# %%
df.shape
# Out:
# (1000, 7)

# %%
data = df.to_dict(orient="records")
data
# Out:
# [{'title': 'White Chicks',
#   'rating': 'PG-13',
#   'ratingLevel': 'crude and sexual humor, language and some drug content',
#   'ratingDescription': 80,
#   'release year': 2004,
#   'user rating score': 82.0,
#   'user rating size': 80},
#  {'title': 'Lucky Number Slevin',
#   'rating': 'R',
#   'ratingLevel': 'strong violence, sexual content and adult language',
#   'ratingDescription': 100,
#   'release year': 2006,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': "Grey's Anatomy",
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2016,
#   'user rating score': 98.0,
#   'user rating size': 80},
#  {'title': 'Prison Break',
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2008,
#   'user rating score': 98.0,
#   'user rating size': 80},
#  {'title': 'How I Met Your Mother',
#   'rating': 'TV-PG',
#   'ratingLevel': 'Parental guidance suggested. May not be suitable for all children.',
#   'ratingDescription': 70,
#   'release year': 2014,
#   'user rating score': 94.0,
#   'user rating size': 80},
#  {'title': 'Supernatural',
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2016,
#   'user rating score': 95.0,
#   'user rating size': 80},
#  {'title': 'Breaking Bad',
#   'rating': 'TV-MA',
#   'ratingLevel': 'For mature audiences.  May not be suitable for children 17 and under.',
#   'ratingDescription': 110,
#   'release year': 2013,
#   'user rating score': 97.0,
#   'user rating size': 80},
#  {'title': 'The Vampire Diaries',
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2017,
#   'user rating score': 91.0,
#   'user rating size': 80},
#  {'title': 'The Walking Dead',
#   'rating': 'TV-MA',
#   'ratingLevel': 'For mature audiences.  May not be suitable for children 17 and under.',
#   'ratingDescription': 110,
#   'release year': 2015,
#   'user rating score': 98.0,
#   'user rating size': 80},
#  {'title': 'Pretty Little Liars',
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2016,
#   'user rating score': 96.0,
#   'user rating size': 80},
#  {'title': 'Once Upon a Time',
#   'rating': 'TV-PG',
#   'ratingLevel': 'Parental guidance suggested. May not be suitable for all children.',
#   'ratingDescription': 70,
#   'release year': 2016,
#   'user rating score': 98.0,
#   'user rating size': 80},
#  {'title': 'Sherlock',
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2016,
#   'user rating score': 95.0,
#   'user rating size': 80},
#  {'title': 'Death Note',
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2006,
#   'user rating score': 77.0,
#   'user rating size': 80},
#  {'title': 'Naruto',
#   'rating': 'TV-PG',
#   'ratingLevel': 'Parental guidance suggested. May not be suitable for all children.',
#   'ratingDescription': 70,
#   'release year': 2008,
#   'user rating score': 88.0,
#   'user rating size': 80},
#  {'title': 'The Hunter',
#   'rating': 'R',
#   'ratingLevel': 'language and brief violence',
#   'ratingDescription': 100,
#   'release year': 2011,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Lottie Dottie Chicken',
#   'rating': 'TV-Y',
#   'ratingLevel': 'Suitable for all ages.',
#   'ratingDescription': 10,
#   'release year': 2009,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Arrow',
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2015,
#   'user rating score': 96.0,
#   'user rating size': 80},
#  {'title': 'Black Mirror',
#   'rating': 'TV-MA',
#   'ratingLevel': 'For mature audiences.  May not be suitable for children 17 and under.',
#   'ratingDescription': 110,
#   'release year': 2016,
#   'user rating score': 80.0,
#   'user rating size': 80},
#  {'title': 'The Originals',
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2016,
#   'user rating score': 74.0,
#   'user rating size': 80},
#  {'title': 'The 100',
#   'rating': 'NR',
#   'ratingLevel': 'This movie has not been rated.',
#   'ratingDescription': 124,
#   'release year': 2016,
#   'user rating score': 97.0,
#   'user rating size': 80},
#  {'title': 'Masha and the Bear',
#   'rating': 'TV-Y',
#   'ratingLevel': 'Suitable for all ages.',
#   'ratingDescription': 10,
#   'release year': 2013,
#   'user rating score': 81.0,
#   'user rating size': 80},
#  {'title': 'Ã“ Pai, Ã“ - Look at This',
#   'rating': 'TV-MA',
#   'ratingLevel': 'For mature audiences.  May not be suitable for children 17 and under.',
#   'ratingDescription': 110,
#   'release year': 2007,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Nymphomaniac: Volume 1',
#   'rating': 'NR',
#   'ratingLevel': 'This movie has not been rated.',
#   'ratingDescription': 124,
#   'release year': 2013,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Hunter X Hunter (2011)',
#   'rating': 'NR',
#   'ratingLevel': 'This movie has not been rated.',
#   'ratingDescription': 124,
#   'release year': 2013,
#   'user rating score': 57.0,
#   'user rating size': 80},
#  {'title': "Marvel's Luke Cage",
#   'rating': 'TV-MA',
#   'ratingLevel': 'For mature audiences.  May not be suitable for children 17 and under.',
#   'ratingDescription': 110,
#   'release year': 2016,
#   'user rating score': 95.0,
#   'user rating size': 80},
#  {'title': "Marvel's Iron Fist",
#   'rating': 'TV-MA',
#   'ratingLevel': nan,
#   'ratingDescription': 110,
#   'release year': 2017,
#   'user rating score': 98.0,
#   'user rating size': 80},
#  {'title': 'Narcos',
#   'rating': 'TV-MA',
#   'ratingLevel': 'For mature audiences.  May not be suitable for children 17 and under.',
#   'ratingDescription': 110,
#   'release year': 2016,
#   'user rating score': 94.0,
#   'user rating size': 80},
#  {'title': 'The Flash',
#   'rating': 'TV-PG',
#   'ratingLevel': 'Parental guidance suggested. May not be suitable for all children.',
#   'ratingDescription': 70,
#   'release year': 2016,
#   'user rating score': 98.0,
#   'user rating size': 80},
#  {'title': 'The Seven Deadly Sins',
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2016,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Scream',
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2016,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'The Do-Over',
#   'rating': 'TV-MA',
#   'ratingLevel': 'For mature audiences.  May not be suitable for children 17 and under.',
#   'ratingDescription': 110,
#   'release year': 2016,
#   'user rating score': 84.0,
#   'user rating size': 80},
#  {'title': 'OperaÃ§Ãµes Especiais',
#   'rating': 'TV-MA',
#   'ratingLevel': nan,
#   'ratingDescription': 110,
#   'release year': 2015,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': '0.03',
#   'rating': 'TV-MA',
#   'ratingLevel': 'For mature audiences.  May not be suitable for children 17 and under.',
#   'ratingDescription': 110,
#   'release year': 2016,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Trollhunters',
#   'rating': 'TV-Y7-FV',
#   'ratingLevel': 'Suitable for children ages 7 and older.  Content contains fantasy violence.',
#   'ratingDescription': 42,
#   'release year': 2016,
#   'user rating score': 83.0,
#   'user rating size': 80},
#  {'title': 'Fearless',
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2016,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Hyena Road',
#   'rating': 'R',
#   'ratingLevel': 'bloody war violence, language throughout and some sexual material',
#   'ratingDescription': 100,
#   'release year': 2015,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Santa Clarita Diet',
#   'rating': 'TV-MA',
#   'ratingLevel': 'For mature audiences.  May not be suitable for children 17 and under.',
#   'ratingDescription': 110,
#   'release year': 2017,
#   'user rating score': 82.0,
#   'user rating size': 80},
#  {'title': 'Sex, Love and Therapy',
#   'rating': 'NR',
#   'ratingLevel': 'This movie has not been rated.',
#   'ratingDescription': 124,
#   'release year': 2014,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'White Girl',
#   'rating': 'UR',
#   'ratingLevel': 'This movie has not been rated. Intended for adults only and may contain sex, violence, drugs, language or other adult themes.',
#   'ratingDescription': 124,
#   'release year': 2016,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Girlboss',
#   'rating': 'TV-MA',
#   'ratingLevel': nan,
#   'ratingDescription': 110,
#   'release year': 2017,
#   'user rating score': 94.0,
#   'user rating size': 80},
#  {'title': 'City of God: 10 Years Later',
#   'rating': 'TV-MA',
#   'ratingLevel': 'For mature audiences.  May not be suitable for children 17 and under.',
#   'ratingDescription': 110,
#   'release year': 2013,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': '13 Reasons Why',
#   'rating': 'TV-MA',
#   'ratingLevel': 'For mature audiences.  May not be suitable for children 17 and under.',
#   'ratingDescription': 110,
#   'release year': 2017,
#   'user rating score': 99.0,
#   'user rating size': 80},
#  {'title': 'Sand Castle',
#   'rating': 'TV-MA',
#   'ratingLevel': nan,
#   'ratingDescription': 110,
#   'release year': 2017,
#   'user rating score': 89.0,
#   'user rating size': 80},
#  {'title': 'Salvador Martinha - Tip of the Tongue',
#   'rating': 'TV-MA',
#   'ratingLevel': 'For mature audiences.  May not be suitable for children 17 and under.',
#   'ratingDescription': 110,
#   'release year': 2016,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Sandy Wexler',
#   'rating': 'TV-14',
#   'ratingLevel': nan,
#   'ratingDescription': 90,
#   'release year': 2017,
#   'user rating score': 92.0,
#   'user rating size': 80},
#  {'title': 'O Amor no DivÃ£',
#   'rating': 'TV-MA',
#   'ratingLevel': nan,
#   'ratingDescription': 110,
#   'release year': 2016,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Stronger Than the World',
#   'rating': 'NR',
#   'ratingLevel': nan,
#   'ratingDescription': 124,
#   'release year': 2016,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Back and Forth',
#   'rating': 'NR',
#   'ratingLevel': 'This movie has not been rated.',
#   'ratingDescription': 124,
#   'release year': 2016,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Happily Married',
#   'rating': 'TV-14',
#   'ratingLevel': nan,
#   'ratingDescription': 90,
#   'release year': 2015,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Pandora',
#   'rating': 'TV-MA',
#   'ratingLevel': nan,
#   'ratingDescription': 110,
#   'release year': 2016,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Lucky Number Slevin',
#   'rating': 'R',
#   'ratingLevel': 'strong violence, sexual content and adult language',
#   'ratingDescription': 100,
#   'release year': 2006,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'The Office (U.S.)',
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2012,
#   'user rating score': 97.0,
#   'user rating size': 80},
#  {'title': "Grey's Anatomy",
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2016,
#   'user rating score': 98.0,
#   'user rating size': 80},
#  {'title': 'Prison Break',
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2008,
#   'user rating score': 98.0,
#   'user rating size': 80},
#  {'title': '90210',
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2013,
#   'user rating score': 62.0,
#   'user rating size': 80},
#  {'title': 'Gossip Girl',
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2012,
#   'user rating score': 96.0,
#   'user rating size': 80},
#  {'title': 'How I Met Your Mother',
#   'rating': 'TV-PG',
#   'ratingLevel': 'Parental guidance suggested. May not be suitable for all children.',
#   'ratingDescription': 70,
#   'release year': 2014,
#   'user rating score': 94.0,
#   'user rating size': 80},
#  {'title': 'Supernatural',
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2016,
#   'user rating score': 95.0,
#   'user rating size': 80},
#  {'title': 'Breaking Bad',
#   'rating': 'TV-MA',
#   'ratingLevel': 'For mature audiences.  May not be suitable for children 17 and under.',
#   'ratingDescription': 110,
#   'release year': 2013,
#   'user rating score': 97.0,
#   'user rating size': 80},
#  {'title': 'Parks and Recreation',
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2015,
#   'user rating score': 94.0,
#   'user rating size': 80},
#  {'title': 'Glee',
#   'rating': 'TV-PG',
#   'ratingLevel': 'Parental guidance suggested. May not be suitable for all children.',
#   'ratingDescription': 70,
#   'release year': 2015,
#   'user rating score': 92.0,
#   'user rating size': 80},
#  {'title': 'The Vampire Diaries',
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2017,
#   'user rating score': 91.0,
#   'user rating size': 80},
#  {'title': 'Family Guy',
#   'rating': 'TV-MA',
#   'ratingLevel': 'For mature audiences.  May not be suitable for children 17 and under.',
#   'ratingDescription': 110,
#   'release year': 2015,
#   'user rating score': 98.0,
#   'user rating size': 80},
#  {'title': 'Criminal Minds',
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2016,
#   'user rating score': 98.0,
#   'user rating size': 80},
#  {'title': 'Friends',
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2003,
#   'user rating score': 98.0,
#   'user rating size': 80},
#  {'title': 'The Secret Life of the American Teenager',
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2013,
#   'user rating score': 81.0,
#   'user rating size': 80},
#  {'title': 'One Tree Hill',
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2011,
#   'user rating score': 90.0,
#   'user rating size': 80},
#  {'title': 'The Walking Dead',
#   'rating': 'TV-MA',
#   'ratingLevel': 'For mature audiences.  May not be suitable for children 17 and under.',
#   'ratingDescription': 110,
#   'release year': 2015,
#   'user rating score': 98.0,
#   'user rating size': 80},
#  {'title': 'Pretty Little Liars',
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2016,
#   'user rating score': 96.0,
#   'user rating size': 80},
#  {'title': 'Shameless (U.S.)',
#   'rating': 'TV-MA',
#   'ratingLevel': 'For mature audiences.  May not be suitable for children 17 and under.',
#   'ratingDescription': 110,
#   'release year': 2016,
#   'user rating score': 97.0,
#   'user rating size': 80},
#  {'title': 'New Girl',
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2016,
#   'user rating score': 91.0,
#   'user rating size': 80},
#  {'title': 'American Horror Story',
#   'rating': 'TV-MA',
#   'ratingLevel': 'For mature audiences.  May not be suitable for children 17 and under.',
#   'ratingDescription': 110,
#   'release year': 2016,
#   'user rating score': 90.0,
#   'user rating size': 80},
#  {'title': 'Orange Is the New Black',
#   'rating': 'TV-MA',
#   'ratingLevel': 'For mature audiences.  May not be suitable for children 17 and under.',
#   'ratingDescription': 110,
#   'release year': 2016,
#   'user rating score': 98.0,
#   'user rating size': 80},
#  {'title': "Inside Russia's Toughest Prison",
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2011,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Black Mirror',
#   'rating': 'TV-MA',
#   'ratingLevel': 'For mature audiences.  May not be suitable for children 17 and under.',
#   'ratingDescription': 110,
#   'release year': 2016,
#   'user rating score': 80.0,
#   'user rating size': 80},
#  {'title': 'Bates Motel',
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2016,
#   'user rating score': 83.0,
#   'user rating size': 80},
#  {'title': 'The 100',
#   'rating': 'NR',
#   'ratingLevel': 'This movie has not been rated.',
#   'ratingDescription': 124,
#   'release year': 2016,
#   'user rating score': 97.0,
#   'user rating size': 80},
#  {'title': "Marvel's Iron Fist",
#   'rating': 'TV-MA',
#   'ratingLevel': nan,
#   'ratingDescription': 110,
#   'release year': 2017,
#   'user rating score': 98.0,
#   'user rating size': 80},
#  {'title': 'Grace and Frankie',
#   'rating': 'TV-MA',
#   'ratingLevel': 'For mature audiences.  May not be suitable for children 17 and under.',
#   'ratingDescription': 110,
#   'release year': 2017,
#   'user rating score': 90.0,
#   'user rating size': 80},
#  {'title': 'How to Get Away with Murder',
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2016,
#   'user rating score': 95.0,
#   'user rating size': 80},
#  {'title': 'The Get Down',
#   'rating': 'TV-MA',
#   'ratingLevel': 'For mature audiences.  May not be suitable for children 17 and under.',
#   'ratingDescription': 110,
#   'release year': 2017,
#   'user rating score': 80.0,
#   'user rating size': 80},
#  {'title': 'Love',
#   'rating': 'TV-MA',
#   'ratingLevel': 'For mature audiences.  May not be suitable for children 17 and under.',
#   'ratingDescription': 110,
#   'release year': 2017,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'The Flash',
#   'rating': 'TV-PG',
#   'ratingLevel': 'Parental guidance suggested. May not be suitable for all children.',
#   'ratingDescription': 70,
#   'release year': 2016,
#   'user rating score': 98.0,
#   'user rating size': 80},
#  {'title': 'The OA',
#   'rating': 'TV-MA',
#   'ratingLevel': 'For mature audiences.  May not be suitable for children 17 and under.',
#   'ratingDescription': 110,
#   'release year': 2016,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Stranger Things',
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2016,
#   'user rating score': 90.0,
#   'user rating size': 80},
#  {'title': 'Ingobernable',
#   'rating': 'TV-MA',
#   'ratingLevel': nan,
#   'ratingDescription': 110,
#   'release year': 2017,
#   'user rating score': 96.0,
#   'user rating size': 80},
#  {'title': 'Zootopia',
#   'rating': 'PG',
#   'ratingLevel': 'some thematic elements, rude humor and action',
#   'ratingDescription': 60,
#   'release year': 2016,
#   'user rating score': 97.0,
#   'user rating size': 80},
#  {'title': 'Meet the Blacks',
#   'rating': 'R',
#   'ratingLevel': 'pervasive language, some sexual material, violence and drug use',
#   'ratingDescription': 100,
#   'release year': 2016,
#   'user rating score': 79.0,
#   'user rating size': 80},
#  {'title': 'Finding Dory',
#   'rating': 'PG',
#   'ratingLevel': 'mild thematic elements',
#   'ratingDescription': 60,
#   'release year': 2016,
#   'user rating score': 98.0,
#   'user rating size': 80},
#  {'title': 'Santa Clarita Diet',
#   'rating': 'TV-MA',
#   'ratingLevel': 'For mature audiences.  May not be suitable for children 17 and under.',
#   'ratingDescription': 110,
#   'release year': 2017,
#   'user rating score': 82.0,
#   'user rating size': 80},
#  {'title': 'Sausage Party',
#   'rating': 'R',
#   'ratingLevel': 'strong crude sexual content, pervasive language, and drug use',
#   'ratingDescription': 100,
#   'release year': 2016,
#   'user rating score': 91.0,
#   'user rating size': 80},
#  {'title': "Pete's Dragon",
#   'rating': 'PG',
#   'ratingLevel': 'for action, peril and brief language',
#   'ratingDescription': 60,
#   'release year': 2016,
#   'user rating score': 93.0,
#   'user rating size': 80},
#  {'title': 'Kevin Hart: What Now?',
#   'rating': 'R',
#   'ratingLevel': 'some sexual material, and language throughout',
#   'ratingDescription': 100,
#   'release year': 2016,
#   'user rating score': 97.0,
#   'user rating size': 80},
#  {'title': 'Girlboss',
#   'rating': 'TV-MA',
#   'ratingLevel': nan,
#   'ratingDescription': 110,
#   'release year': 2017,
#   'user rating score': 94.0,
#   'user rating size': 80},
#  {'title': 'The Discovery',
#   'rating': 'TV-MA',
#   'ratingLevel': nan,
#   'ratingDescription': 110,
#   'release year': 2017,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Sand Castle',
#   'rating': 'TV-MA',
#   'ratingLevel': nan,
#   'ratingDescription': 110,
#   'release year': 2017,
#   'user rating score': 89.0,
#   'user rating size': 80},
#  {'title': 'Sandy Wexler',
#   'rating': 'TV-14',
#   'ratingLevel': nan,
#   'ratingDescription': 90,
#   'release year': 2017,
#   'user rating score': 92.0,
#   'user rating size': 80},
#  {'title': 'Chewing Gum',
#   'rating': 'TV-MA',
#   'ratingLevel': 'For mature audiences.  May not be suitable for children 17 and under.',
#   'ratingDescription': 110,
#   'release year': 2017,
#   'user rating score': 93.0,
#   'user rating size': 80},
#  {'title': 'Cheer Squad',
#   'rating': 'TV-PG',
#   'ratingLevel': nan,
#   'ratingDescription': 70,
#   'release year': 2016,
#   'user rating score': 61.0,
#   'user rating size': 80},
#  {'title': 'Only for One Night',
#   'rating': 'TV-MA',
#   'ratingLevel': nan,
#   'ratingDescription': 110,
#   'release year': 2016,
#   'user rating score': 78.0,
#   'user rating size': 80},
#  {'title': 'The Life Aquatic with Steve Zissou',
#   'rating': 'R',
#   'ratingLevel': 'language, some drug use, violence and partial nudity',
#   'ratingDescription': 100,
#   'release year': 2004,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Lucky Number Slevin',
#   'rating': 'R',
#   'ratingLevel': 'strong violence, sexual content and adult language',
#   'ratingDescription': 100,
#   'release year': 2006,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'The L Word',
#   'rating': 'TV-MA',
#   'ratingLevel': 'For mature audiences.  May not be suitable for children 17 and under.',
#   'ratingDescription': 110,
#   'release year': 2009,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'The Office (U.S.)',
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2012,
#   'user rating score': 97.0,
#   'user rating size': 80},
#  {'title': '30 Rock',
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2012,
#   'user rating score': 66.0,
#   'user rating size': 80},
#  {'title': 'Mad Men',
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2014,
#   'user rating score': 75.0,
#   'user rating size': 80},
#  {'title': "It's Always Sunny in Philadelphia",
#   'rating': 'TV-MA',
#   'ratingLevel': 'For mature audiences.  May not be suitable for children 17 and under.',
#   'ratingDescription': 110,
#   'release year': 2016,
#   'user rating score': 91.0,
#   'user rating size': 80},
#  {'title': 'Californication',
#   'rating': 'TV-MA',
#   'ratingLevel': 'For mature audiences.  May not be suitable for children 17 and under.',
#   'ratingDescription': 110,
#   'release year': 2014,
#   'user rating score': 63.0,
#   'user rating size': 80},
#  {'title': 'Parks and Recreation',
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2015,
#   'user rating score': 94.0,
#   'user rating size': 80},
#  {'title': 'Friends',
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2003,
#   'user rating score': 98.0,
#   'user rating size': 80},
#  {'title': 'Shameless (U.S.)',
#   'rating': 'TV-MA',
#   'ratingLevel': 'For mature audiences.  May not be suitable for children 17 and under.',
#   'ratingDescription': 110,
#   'release year': 2016,
#   'user rating score': 97.0,
#   'user rating size': 80},
#  {'title': 'Portlandia',
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2016,
#   'user rating score': 62.0,
#   'user rating size': 80},
#  {'title': 'New Girl',
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2016,
#   'user rating score': 91.0,
#   'user rating size': 80},
#  {'title': "Don't Trust the B---- in Apartment 23",
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2012,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Friends with Benefits',
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2011,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'The Client List',
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2013,
#   'user rating score': 92.0,
#   'user rating size': 80},
#  {'title': 'Halt and Catch Fire',
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2016,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': '5 to 7',
#   'rating': 'R',
#   'ratingLevel': 'some sexual material',
#   'ratingDescription': 100,
#   'release year': 2014,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': "Marvel's Iron Fist",
#   'rating': 'TV-MA',
#   'ratingLevel': nan,
#   'ratingDescription': 110,
#   'release year': 2017,
#   'user rating score': 98.0,
#   'user rating size': 80},
#  {'title': "Chef's Table",
#   'rating': 'TV-MA',
#   'ratingLevel': 'For mature audiences.  May not be suitable for children 17 and under.',
#   'ratingDescription': 110,
#   'release year': 2017,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Documentary Now!',
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2016,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Grace and Frankie',
#   'rating': 'TV-MA',
#   'ratingLevel': 'For mature audiences.  May not be suitable for children 17 and under.',
#   'ratingDescription': 110,
#   'release year': 2017,
#   'user rating score': 90.0,
#   'user rating size': 80},
#  {'title': 'Better Call Saul',
#   'rating': 'TV-MA',
#   'ratingLevel': 'For mature audiences.  May not be suitable for children 17 and under.',
#   'ratingDescription': 110,
#   'release year': 2016,
#   'user rating score': 95.0,
#   'user rating size': 80},
#  {'title': 'The Get Down',
#   'rating': 'TV-MA',
#   'ratingLevel': 'For mature audiences.  May not be suitable for children 17 and under.',
#   'ratingDescription': 110,
#   'release year': 2017,
#   'user rating score': 80.0,
#   'user rating size': 80},
#  {'title': "Schitt's Creek",
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2016,
#   'user rating score': 74.0,
#   'user rating size': 80},
#  {'title': 'Lovesick',
#   'rating': 'TV-MA',
#   'ratingLevel': 'For mature audiences.  May not be suitable for children 17 and under.',
#   'ratingDescription': 110,
#   'release year': 2016,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Flaked',
#   'rating': 'TV-MA',
#   'ratingLevel': 'For mature audiences.  May not be suitable for children 17 and under.',
#   'ratingDescription': 110,
#   'release year': 2016,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Master of None',
#   'rating': 'TV-MA',
#   'ratingLevel': 'For mature audiences.  May not be suitable for children 17 and under.',
#   'ratingDescription': 110,
#   'release year': 2015,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Chelsea',
#   'rating': 'TV-MA',
#   'ratingLevel': 'For mature audiences.  May not be suitable for children 17 and under.',
#   'ratingDescription': 110,
#   'release year': 2017,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Abstract: The Art of Design',
#   'rating': 'TV-14',
#   'ratingLevel': nan,
#   'ratingDescription': 90,
#   'release year': 2017,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': "Cooper Barrett's Guide to Surviving Life",
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2016,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'The Great British Baking Show',
#   'rating': 'TV-PG',
#   'ratingLevel': 'Parental guidance suggested. May not be suitable for all children.',
#   'ratingDescription': 70,
#   'release year': 2016,
#   'user rating score': 94.0,
#   'user rating size': 80},
#  {'title': 'Life in Pieces',
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2015,
#   'user rating score': 68.0,
#   'user rating size': 80},
#  {'title': 'Crazy Ex-Girlfriend',
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2017,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Easy',
#   'rating': 'TV-MA',
#   'ratingLevel': 'For mature audiences.  May not be suitable for children 17 and under.',
#   'ratingDescription': 110,
#   'release year': 2016,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Santa Clarita Diet',
#   'rating': 'TV-MA',
#   'ratingLevel': 'For mature audiences.  May not be suitable for children 17 and under.',
#   'ratingDescription': 110,
#   'release year': 2017,
#   'user rating score': 82.0,
#   'user rating size': 80},
#  {'title': 'No Tomorrow',
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2016,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Minimalism: A Documentary About the Important Things',
#   'rating': 'TV-PG',
#   'ratingLevel': nan,
#   'ratingDescription': 70,
#   'release year': 2016,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Girlboss',
#   'rating': 'TV-MA',
#   'ratingLevel': nan,
#   'ratingDescription': 110,
#   'release year': 2017,
#   'user rating score': 94.0,
#   'user rating size': 80},
#  {'title': 'Hot Girls Wanted: Turned On',
#   'rating': 'TV-MA',
#   'ratingLevel': nan,
#   'ratingDescription': 110,
#   'release year': 2017,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'The Discovery',
#   'rating': 'TV-MA',
#   'ratingLevel': nan,
#   'ratingDescription': 110,
#   'release year': 2017,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': '13 Reasons Why',
#   'rating': 'TV-MA',
#   'ratingLevel': 'For mature audiences.  May not be suitable for children 17 and under.',
#   'ratingDescription': 110,
#   'release year': 2017,
#   'user rating score': 99.0,
#   'user rating size': 80},
#  {'title': 'Sandy Wexler',
#   'rating': 'TV-14',
#   'ratingLevel': nan,
#   'ratingDescription': 90,
#   'release year': 2017,
#   'user rating score': 92.0,
#   'user rating size': 80},
#  {'title': 'Chewing Gum',
#   'rating': 'TV-MA',
#   'ratingLevel': 'For mature audiences.  May not be suitable for children 17 and under.',
#   'ratingDescription': 110,
#   'release year': 2017,
#   'user rating score': 93.0,
#   'user rating size': 80},
#  {'title': 'Win It All',
#   'rating': 'TV-MA',
#   'ratingLevel': nan,
#   'ratingDescription': 110,
#   'release year': 2017,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'MerlÃ\xad',
#   'rating': 'TV-PG',
#   'ratingLevel': 'Parental guidance suggested. May not be suitable for all children.',
#   'ratingDescription': 70,
#   'release year': 2015,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Amy Schumer: The Leather Special',
#   'rating': 'TV-MA',
#   'ratingLevel': nan,
#   'ratingDescription': 110,
#   'release year': 2017,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Louis C.K. 2017',
#   'rating': 'TV-MA',
#   'ratingLevel': nan,
#   'ratingDescription': 110,
#   'release year': 2017,
#   'user rating score': 71.0,
#   'user rating size': 80},
#  {'title': 'Dave Chappelle',
#   'rating': 'TV-MA',
#   'ratingLevel': 'For mature audiences.  May not be suitable for children 17 and under.',
#   'ratingDescription': 110,
#   'release year': 2017,
#   'user rating score': 94.0,
#   'user rating size': 80},
#  {'title': 'Almost Adults',
#   'rating': 'NR',
#   'ratingLevel': 'This movie has not been rated.',
#   'ratingDescription': 124,
#   'release year': 2016,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'The Brothers',
#   'rating': 'R',
#   'ratingLevel': 'strong sexual content and language',
#   'ratingDescription': 100,
#   'release year': 2001,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Skins',
#   'rating': 'TV-MA',
#   'ratingLevel': 'For mature audiences.  May not be suitable for children 17 and under.',
#   'ratingDescription': 110,
#   'release year': 2013,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'The Cleveland Show',
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2012,
#   'user rating score': 88.0,
#   'user rating size': 80},
#  {'title': 'Absolutely Fabulous',
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2012,
#   'user rating score': 59.0,
#   'user rating size': 80},
#  {'title': "Don't Trust the B---- in Apartment 23",
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2012,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Raising Hope',
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2013,
#   'user rating score': 73.0,
#   'user rating size': 80},
#  {'title': 'Come Fly With Me',
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2010,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Orange Is the New Black',
#   'rating': 'TV-MA',
#   'ratingLevel': 'For mature audiences.  May not be suitable for children 17 and under.',
#   'ratingDescription': 110,
#   'release year': 2016,
#   'user rating score': 98.0,
#   'user rating size': 80},
#  {'title': 'Brickleberry',
#   'rating': 'TV-MA',
#   'ratingLevel': 'For mature audiences.  May not be suitable for children 17 and under.',
#   'ratingDescription': 110,
#   'release year': 2014,
#   'user rating score': 63.0,
#   'user rating size': 80},
#  {'title': 'Bates Motel',
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2016,
#   'user rating score': 83.0,
#   'user rating size': 80},
#  {'title': 'BoJack Horseman',
#   'rating': 'TV-MA',
#   'ratingLevel': 'For mature audiences.  May not be suitable for children 17 and under.',
#   'ratingDescription': 110,
#   'release year': 2016,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Being Mary Jane: The Series',
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2016,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Documentary Now!',
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2016,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Grace and Frankie',
#   'rating': 'TV-MA',
#   'ratingLevel': 'For mature audiences.  May not be suitable for children 17 and under.',
#   'ratingDescription': 110,
#   'release year': 2017,
#   'user rating score': 90.0,
#   'user rating size': 80},
#  {'title': 'Unbreakable Kimmy Schmidt',
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2016,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'The Get Down',
#   'rating': 'TV-MA',
#   'ratingLevel': 'For mature audiences.  May not be suitable for children 17 and under.',
#   'ratingDescription': 110,
#   'release year': 2017,
#   'user rating score': 80.0,
#   'user rating size': 80},
#  {'title': 'Love',
#   'rating': 'TV-MA',
#   'ratingLevel': 'For mature audiences.  May not be suitable for children 17 and under.',
#   'ratingDescription': 110,
#   'release year': 2017,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Bordertown',
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2016,
#   'user rating score': 86.0,
#   'user rating size': 80},
#  {'title': 'Jane The Virgin',
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2016,
#   'user rating score': 91.0,
#   'user rating size': 80},
#  {'title': "Schitt's Creek",
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2016,
#   'user rating score': 74.0,
#   'user rating size': 80},
#  {'title': 'Dope',
#   'rating': 'R',
#   'ratingLevel': 'language, drug content, sexuality/nudity, and some violence-all involving teens',
#   'ratingDescription': 100,
#   'release year': 2015,
#   'user rating score': 79.0,
#   'user rating size': 80},
#  {'title': 'Lovesick',
#   'rating': 'TV-MA',
#   'ratingLevel': 'For mature audiences.  May not be suitable for children 17 and under.',
#   'ratingDescription': 110,
#   'release year': 2016,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'The Carmichael Show',
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2016,
#   'user rating score': 69.0,
#   'user rating size': 80},
#  {'title': "Cooper Barrett's Guide to Surviving Life",
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2016,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'The Great British Baking Show',
#   'rating': 'TV-PG',
#   'ratingLevel': 'Parental guidance suggested. May not be suitable for all children.',
#   'ratingDescription': 70,
#   'release year': 2016,
#   'user rating score': 94.0,
#   'user rating size': 80},
#  {'title': 'November Rule',
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2015,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Life in Pieces',
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2015,
#   'user rating score': 68.0,
#   'user rating size': 80},
#  {'title': 'Crazy Ex-Girlfriend',
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2017,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Easy',
#   'rating': 'TV-MA',
#   'ratingLevel': 'For mature audiences.  May not be suitable for children 17 and under.',
#   'ratingDescription': 110,
#   'release year': 2016,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Haters Back Off',
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2016,
#   'user rating score': 58.0,
#   'user rating size': 80},
#  {'title': 'Kubo and the Two Strings',
#   'rating': 'PG',
#   'ratingLevel': 'thematic elements, scary images, action and peril',
#   'ratingDescription': 60,
#   'release year': 2016,
#   'user rating score': 96.0,
#   'user rating size': 80},
#  {'title': 'Skins',
#   'rating': 'TV-MA',
#   'ratingLevel': nan,
#   'ratingDescription': 110,
#   'release year': 2017,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'A Weekend with the Family',
#   'rating': 'TV-MA',
#   'ratingLevel': 'For mature audiences.  May not be suitable for children 17 and under.',
#   'ratingDescription': 110,
#   'release year': 2016,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Crazyhead',
#   'rating': 'TV-MA',
#   'ratingLevel': 'For mature audiences.  May not be suitable for children 17 and under.',
#   'ratingDescription': 110,
#   'release year': 2016,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Queen of Katwe',
#   'rating': 'PG',
#   'ratingLevel': 'thematic elements, an accident scene and some suggestive material',
#   'ratingDescription': 60,
#   'release year': 2016,
#   'user rating score': nan,
#   'user rating size': 81},
#  {'title': 'Little Boxes',
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2016,
#   'user rating score': 61.0,
#   'user rating size': 80},
#  {'title': 'Deidra & Laney Rob a Train',
#   'rating': 'TV-14',
#   'ratingLevel': nan,
#   'ratingDescription': 90,
#   'release year': 2017,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Girlboss',
#   'rating': 'TV-MA',
#   'ratingLevel': nan,
#   'ratingDescription': 110,
#   'release year': 2017,
#   'user rating score': 94.0,
#   'user rating size': 80},
#  {'title': 'Hot Girls Wanted: Turned On',
#   'rating': 'TV-MA',
#   'ratingLevel': nan,
#   'ratingDescription': 110,
#   'release year': 2017,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': '13 Reasons Why',
#   'rating': 'TV-MA',
#   'ratingLevel': 'For mature audiences.  May not be suitable for children 17 and under.',
#   'ratingDescription': 110,
#   'release year': 2017,
#   'user rating score': 99.0,
#   'user rating size': 80},
#  {'title': 'Hurricane Bianca',
#   'rating': 'TV-MA',
#   'ratingLevel': nan,
#   'ratingDescription': 110,
#   'release year': 2016,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Honeytrap',
#   'rating': 'NR',
#   'ratingLevel': 'This movie has not been rated.',
#   'ratingDescription': 124,
#   'release year': 2014,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Greenleaf',
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2016,
#   'user rating score': 62.0,
#   'user rating size': 80},
#  {'title': 'Lazy Eye',
#   'rating': 'TV-MA',
#   'ratingLevel': nan,
#   'ratingDescription': 110,
#   'release year': 2016,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Like Cotton Twines',
#   'rating': 'NR',
#   'ratingLevel': nan,
#   'ratingDescription': 124,
#   'release year': 2016,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'The Wedding Party',
#   'rating': 'TV-14',
#   'ratingLevel': nan,
#   'ratingDescription': 90,
#   'release year': 2016,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Dave Chappelle',
#   'rating': 'TV-MA',
#   'ratingLevel': 'For mature audiences.  May not be suitable for children 17 and under.',
#   'ratingDescription': 110,
#   'release year': 2017,
#   'user rating score': 94.0,
#   'user rating size': 80},
#  {'title': 'Only for One Night',
#   'rating': 'TV-MA',
#   'ratingLevel': nan,
#   'ratingDescription': 110,
#   'release year': 2016,
#   'user rating score': 78.0,
#   'user rating size': 80},
#  {'title': 'Boy Bye',
#   'rating': 'TV-MA',
#   'ratingLevel': nan,
#   'ratingDescription': 110,
#   'release year': 2016,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Almost Adults',
#   'rating': 'NR',
#   'ratingLevel': 'This movie has not been rated.',
#   'ratingDescription': 124,
#   'release year': 2016,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Nancy Drew',
#   'rating': 'PG',
#   'ratingLevel': 'Parental guidance suggested. May not be suitable for children.',
#   'ratingDescription': 60,
#   'release year': 2007,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': '30 Rock',
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2012,
#   'user rating score': 66.0,
#   'user rating size': 80},
#  {'title': 'Nurse Jackie',
#   'rating': 'TV-MA',
#   'ratingLevel': 'For mature audiences.  May not be suitable for children 17 and under.',
#   'ratingDescription': 110,
#   'release year': 2015,
#   'user rating score': 82.0,
#   'user rating size': 80},
#  {'title': 'Parks and Recreation',
#   'rating': 'TV-14',
#   'ratingLevel': 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.',
#   'ratingDescription': 90,
#   'release year': 2015,
#   'user rating score': 94.0,
#   'user rating size': 80},
#  {'title': 'Drop Dead Diva',
#   'rating': 'TV-PG',
#   'ratingLevel': 'Parental guidance suggested. May not be suitable for all children.',
#   'ratingDescription': 70,
#   'release year': 2014,
# ...
#   'release year': 2004,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'The Last Unicorn',
#   'rating': 'G',
#   'ratingLevel': 'General Audiences. Suitable for all ages.',
#   'ratingDescription': 35,
#   'release year': 1982,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'The Iron Giant',
#   'rating': 'PG',
#   'ratingLevel': 'fantasy action and mild language',
#   'ratingDescription': 60,
#   'release year': 1999,
#   'user rating score': 83.0,
#   'user rating size': 80},
#  {'title': 'Mulan 2',
#   'rating': 'G',
#   'ratingLevel': 'General Audiences. Suitable for all ages.',
#   'ratingDescription': 35,
#   'release year': 2004,
#   'user rating score': 85.0,
#   'user rating size': 80},
#  {'title': "Pooh's Heffalump Movie",
#   'rating': 'G',
#   'ratingLevel': 'General Audiences. Suitable for all ages.',
#   'ratingDescription': 35,
#   'release year': 2005,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': "Kronk's New Groove",
#   'rating': 'G',
#   'ratingLevel': 'General Audiences. Suitable for all ages.',
#   'ratingDescription': 35,
#   'release year': 2005,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Corpse Bride',
#   'rating': 'PG',
#   'ratingLevel': 'some scary images and action, and brief mild language',
#   'ratingDescription': 60,
#   'release year': 2005,
#   'user rating score': 91.0,
#   'user rating size': 80},
#  {'title': 'Brother Bear 2',
#   'rating': 'G',
#   'ratingLevel': 'General Audiences. Suitable for all ages.',
#   'ratingDescription': 35,
#   'release year': 2006,
#   'user rating score': 57.0,
#   'user rating size': 80},
#  {'title': 'The Smurfs and the Magic Flute',
#   'rating': 'G',
#   'ratingLevel': 'General Audiences. Suitable for all ages.',
#   'ratingDescription': 35,
#   'release year': 1976,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Jetsons: The Movie',
#   'rating': 'G',
#   'ratingLevel': 'General Audiences. Suitable for all ages.',
#   'ratingDescription': 35,
#   'release year': 1990,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': "We're Back! A Dinosaur's Story",
#   'rating': 'G',
#   'ratingLevel': 'General Audiences. Suitable for all ages.',
#   'ratingDescription': 35,
#   'release year': 1993,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Ernest & Celestine',
#   'rating': 'PG',
#   'ratingLevel': 'some scary moments',
#   'ratingDescription': 60,
#   'release year': 2012,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Animaniacs',
#   'rating': 'TV-Y7',
#   'ratingLevel': 'Suitable for children ages 7 and older',
#   'ratingDescription': 41,
#   'release year': 1997,
#   'user rating score': 72.0,
#   'user rating size': 80},
#  {'title': 'Disney Animation Collection: Vol. 1: Mickey and the Beanstalk',
#   'rating': 'TV-G',
#   'ratingLevel': 'Suitable for all ages.',
#   'ratingDescription': 35,
#   'release year': 2009,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Disney Animation Collection: Vol. 2: Three Little Pigs',
#   'rating': 'TV-G',
#   'ratingLevel': 'Suitable for all ages.',
#   'ratingDescription': 35,
#   'release year': 2009,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Disney Animation Collection: Vol. 4: The Tortoise and the Hare',
#   'rating': 'TV-G',
#   'ratingLevel': 'Suitable for all ages.',
#   'ratingDescription': 35,
#   'release year': 2009,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'The Pirate Fairy',
#   'rating': 'G',
#   'ratingLevel': 'General Audiences. Suitable for all ages.',
#   'ratingDescription': 35,
#   'release year': 2014,
#   'user rating score': 57.0,
#   'user rating size': 80},
#  {'title': 'Underdogs',
#   'rating': 'PG',
#   'ratingLevel': 'Parental guidance suggested. May not be suitable for children.',
#   'ratingDescription': 60,
#   'release year': 2013,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'The Boxcar Children',
#   'rating': 'G',
#   'ratingLevel': 'General Audiences. Suitable for all ages.',
#   'ratingDescription': 35,
#   'release year': 2014,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Ribbit',
#   'rating': 'PG',
#   'ratingLevel': 'some peril',
#   'ratingDescription': 60,
#   'release year': 2014,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Yellowbird',
#   'rating': 'PG',
#   'ratingLevel': 'Parental guidance suggested. May not be suitable for children.',
#   'ratingDescription': 60,
#   'release year': 2014,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Octonauts',
#   'rating': 'TV-Y',
#   'ratingLevel': 'Suitable for all ages.',
#   'ratingDescription': 10,
#   'release year': 2015,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'The Land Before Time XIV: Journey of the Brave',
#   'rating': 'G',
#   'ratingLevel': 'General Audiences. Suitable for all ages.',
#   'ratingDescription': 35,
#   'release year': 2016,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Quackerz',
#   'rating': 'PG',
#   'ratingLevel': 'rude and suggestive humor, and some action',
#   'ratingDescription': 60,
#   'release year': 2016,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Growing Up Wild',
#   'rating': 'G',
#   'ratingLevel': nan,
#   'ratingDescription': 35,
#   'release year': 2016,
#   'user rating score': 80.0,
#   'user rating size': 80},
#  {'title': 'Cool Runnings',
#   'rating': 'PG',
#   'ratingLevel': 'Parental guidance suggested. May not be suitable for children.',
#   'ratingDescription': 60,
#   'release year': 1993,
#   'user rating score': 81.0,
#   'user rating size': 80},
#  {'title': 'Mr. Magoo',
#   'rating': 'PG',
#   'ratingLevel': 'mild language and action sequences',
#   'ratingDescription': 60,
#   'release year': 1997,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Flubber',
#   'rating': 'PG',
#   'ratingLevel': 'slapstick action and mild language',
#   'ratingDescription': 60,
#   'release year': 1997,
#   'user rating score': 83.0,
#   'user rating size': 80},
#  {'title': 'Anastasia',
#   'rating': 'G',
#   'ratingLevel': 'General Audiences. Suitable for all ages.',
#   'ratingDescription': 35,
#   'release year': 1997,
#   'user rating score': 93.0,
#   'user rating size': 80},
#  {'title': 'Antz',
#   'rating': 'PG',
#   'ratingLevel': 'moderate adult language and intense action',
#   'ratingDescription': 60,
#   'release year': 1998,
#   'user rating score': 80.0,
#   'user rating size': 80},
#  {'title': 'Babe: Pig in the City',
#   'rating': 'G',
#   'ratingLevel': 'General Audiences. Suitable for all ages.',
#   'ratingDescription': 35,
#   'release year': 1998,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Paulie',
#   'rating': 'PG',
#   'ratingLevel': 'Parental guidance suggested. May not be suitable for children.',
#   'ratingDescription': 60,
#   'release year': 1998,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'The Road to El Dorado',
#   'rating': 'PG',
#   'ratingLevel': 'mild thematic material and language',
#   'ratingDescription': 60,
#   'release year': 2000,
#   'user rating score': 91.0,
#   'user rating size': 80},
#  {'title': 'Air Bud: World Pup',
#   'rating': 'G',
#   'ratingLevel': 'General Audiences. Suitable for all ages.',
#   'ratingDescription': 35,
#   'release year': 2000,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'An American Tail',
#   'rating': 'G',
#   'ratingLevel': 'General Audiences. Suitable for all ages.',
#   'ratingDescription': 35,
#   'release year': 1986,
#   'user rating score': 67.0,
#   'user rating size': 80},
#  {'title': 'Harry and the Hendersons',
#   'rating': 'PG',
#   'ratingLevel': 'Parental guidance suggested. May not be suitable for children.',
#   'ratingDescription': 60,
#   'release year': 1987,
#   'user rating score': 58.0,
#   'user rating size': 80},
#  {'title': 'Cats & Dogs',
#   'rating': 'PG',
#   'ratingLevel': 'animal action and humor',
#   'ratingDescription': 60,
#   'release year': 2001,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': "Baby's Day Out",
#   'rating': 'PG',
#   'ratingLevel': 'mild language and comic action',
#   'ratingDescription': 60,
#   'release year': 1994,
#   'user rating score': 71.0,
#   'user rating size': 80},
#  {'title': 'Balto 2: Wolf Quest',
#   'rating': 'G',
#   'ratingLevel': 'General Audiences. Suitable for all ages.',
#   'ratingDescription': 35,
#   'release year': 2001,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Balto',
#   'rating': 'G',
#   'ratingLevel': 'General Audiences. Suitable for all ages.',
#   'ratingDescription': 35,
#   'release year': 1995,
#   'user rating score': 64.0,
#   'user rating size': 80},
#  {'title': 'Back to the Secret Garden',
#   'rating': 'G',
#   'ratingLevel': 'General Audiences. Suitable for all ages.',
#   'ratingDescription': 35,
#   'release year': 2002,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Blank Check',
#   'rating': 'PG',
#   'ratingLevel': 'Parental guidance suggested. May not be suitable for children.',
#   'ratingDescription': 60,
#   'release year': 1994,
#   'user rating score': 93.0,
#   'user rating size': 80},
#  {'title': 'Heavyweights',
#   'rating': 'PG',
#   'ratingLevel': 'some rude language and pranks',
#   'ratingDescription': 60,
#   'release year': 1995,
#   'user rating score': 74.0,
#   'user rating size': 80},
#  {'title': 'Inspector Gadget 2',
#   'rating': 'G',
#   'ratingLevel': 'General Audiences. Suitable for all ages.',
#   'ratingDescription': 35,
#   'release year': 2003,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Air Bud: Spikes Back',
#   'rating': 'G',
#   'ratingLevel': 'General Audiences. Suitable for all ages.',
#   'ratingDescription': 35,
#   'release year': 2003,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Annie',
#   'rating': 'PG',
#   'ratingLevel': 'adult content and mld violence',
#   'ratingDescription': 60,
#   'release year': 1982,
#   'user rating score': 68.0,
#   'user rating size': 80},
#  {'title': 'An American Tail: Fievel Goes West',
#   'rating': 'G',
#   'ratingLevel': 'General Audiences. Suitable for all ages.',
#   'ratingDescription': 35,
#   'release year': 1991,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'D2: The Mighty Ducks',
#   'rating': 'PG',
#   'ratingLevel': 'some mild language and rough hockey action',
#   'ratingDescription': 60,
#   'release year': 1994,
#   'user rating score': 70.0,
#   'user rating size': 80},
#  {'title': 'Honey, I Shrunk the Kids',
#   'rating': 'PG',
#   'ratingLevel': 'Parental guidance suggested. May not be suitable for children.',
#   'ratingDescription': 60,
#   'release year': 1989,
#   'user rating score': 80.0,
#   'user rating size': 80},
#  {'title': 'The Iron Giant',
#   'rating': 'PG',
#   'ratingLevel': 'fantasy action and mild language',
#   'ratingDescription': 60,
#   'release year': 1999,
#   'user rating score': 83.0,
#   'user rating size': 80},
#  {'title': 'The Fox and the Hound 2',
#   'rating': 'G',
#   'ratingLevel': 'General Audiences. Suitable for all ages.',
#   'ratingDescription': 35,
#   'release year': 2006,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Air Buddies',
#   'rating': 'PG',
#   'ratingLevel': 'some mild, rude humor',
#   'ratingDescription': 60,
#   'release year': 2006,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Dr. Dolittle: Tail to the Chief',
#   'rating': 'PG',
#   'ratingLevel': 'brief mild language and some rude behavior',
#   'ratingDescription': 60,
#   'release year': 2008,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Flicka 2',
#   'rating': 'PG',
#   'ratingLevel': 'some reckless behavior',
#   'ratingDescription': 60,
#   'release year': 2010,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'H2O: Just Add Water',
#   'rating': 'TV-PG',
#   'ratingLevel': 'Parental guidance suggested. May not be suitable for all children.',
#   'ratingDescription': 70,
#   'release year': 2009,
#   'user rating score': 74.0,
#   'user rating size': 80},
#  {'title': 'The Gruffalo',
#   'rating': 'TV-Y',
#   'ratingLevel': 'Suitable for all ages.',
#   'ratingDescription': 10,
#   'release year': 2009,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Dolphin Tale',
#   'rating': 'PG',
#   'ratingLevel': 'some mild thematic elements',
#   'ratingDescription': 60,
#   'release year': 2011,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Pound Puppies',
#   'rating': 'TV-Y',
#   'ratingLevel': 'Suitable for all ages.',
#   'ratingDescription': 10,
#   'release year': 2013,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Beverly Hills Chihuahua 3: Viva La Fiesta!',
#   'rating': 'G',
#   'ratingLevel': 'General Audiences. Suitable for all ages.',
#   'ratingDescription': 35,
#   'release year': 2012,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'The Magic School Bus',
#   'rating': 'TV-Y',
#   'ratingLevel': 'Suitable for all ages.',
#   'ratingDescription': 10,
#   'release year': 1997,
#   'user rating score': 81.0,
#   'user rating size': 80},
#  {'title': 'Step Dogs',
#   'rating': 'TV-PG',
#   'ratingLevel': 'Parental guidance suggested. May not be suitable for all children.',
#   'ratingDescription': 70,
#   'release year': 2013,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'PokÃ©mon: Indigo League',
#   'rating': 'TV-Y',
#   'ratingLevel': 'Suitable for all ages.',
#   'ratingDescription': 10,
#   'release year': 2000,
#   'user rating score': 74.0,
#   'user rating size': 80},
#  {'title': 'Mia and Me',
#   'rating': 'TV-Y',
#   'ratingLevel': 'Suitable for all ages.',
#   'ratingDescription': 10,
#   'release year': 2015,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Paddington',
#   'rating': 'PG',
#   'ratingLevel': 'mild action and rude humor',
#   'ratingDescription': 60,
#   'release year': 2014,
#   'user rating score': 70.0,
#   'user rating size': 80},
#  {'title': 'Russell Madness',
#   'rating': 'PG',
#   'ratingLevel': 'some rude humor and sports action',
#   'ratingDescription': 60,
#   'release year': 2015,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'My Animal Friends',
#   'rating': 'TV-Y',
#   'ratingLevel': 'Suitable for all ages.',
#   'ratingDescription': 10,
#   'release year': 2013,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Dawn of the Croods',
#   'rating': 'TV-Y7',
#   'ratingLevel': 'Suitable for children ages 7 and older',
#   'ratingDescription': 41,
#   'release year': 2017,
#   'user rating score': 72.0,
#   'user rating size': 80},
#  {'title': 'Alpha and Omega: Dino Digs',
#   'rating': 'TV-G',
#   'ratingLevel': 'Suitable for all ages.',
#   'ratingDescription': 35,
#   'release year': 2016,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Wiener Dog Internationals',
#   'rating': 'G',
#   'ratingLevel': 'General Audiences. Suitable for all ages.',
#   'ratingDescription': 35,
#   'release year': 2015,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Pup Star',
#   'rating': 'G',
#   'ratingLevel': 'General Audiences. Suitable for all ages.',
#   'ratingDescription': 35,
#   'release year': 2016,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'The BFG',
#   'rating': 'PG',
#   'ratingLevel': 'for action/peril, some scary moments and brief rude humor',
#   'ratingDescription': 60,
#   'release year': 2016,
#   'user rating score': 97.0,
#   'user rating size': 80},
#  {'title': 'The Secret Life of Pets',
#   'rating': 'PG',
#   'ratingLevel': 'for action and some rude humor',
#   'ratingDescription': 60,
#   'release year': 2016,
#   'user rating score': nan,
#   'user rating size': 81},
#  {'title': 'Precious Puppies',
#   'rating': 'TV-G',
#   'ratingLevel': 'Suitable for all ages.',
#   'ratingDescription': 35,
#   'release year': 2003,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Beary Tales',
#   'rating': 'TV-G',
#   'ratingLevel': 'Suitable for all ages.',
#   'ratingDescription': 35,
#   'release year': 2013,
#   'user rating score': nan,
#   'user rating size': 82},
#  {'title': 'Growing Up Wild',
#   'rating': 'G',
#   'ratingLevel': nan,
#   'ratingDescription': 35,
#   'release year': 2016,
#   'user rating score': 80.0,
#   'user rating size': 80}]

# %%
db = client["netflix"]

# %%
print(db)
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'netflix')

# %%
db.Netflix.insert_many(data)
