# %%
# !pip install pymysql
# Out:
# ...
#   Using cached PyMySQL-1.0.2-py3-none-any.whl (43 kB)
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine(f"mysql+pymysql://testuser:testuser@127.0.0.1:3306/testdb")
df = pd.read_sql("SELECT * FROM TESTDB.Medinst_HospPharmacyOpCloList", con=engine)

df
# Out:
#                                                    addr clCdNm    cnclDd  \
# 0                 서울특별시 송파구 위례서로 248, 지하1층, 5~12층 (거여동)     병원      None
# 1                              서울특별시 광진구 동일로 82-1 (자양동)   요양병원  20210218
# 2                  서울특별시 강동구 고덕로 295-60, 원케어메디컬타운 (고덕동)   요양병원  20210219
# 3             서울특별시 서초구 신반포로 45, K동 10호 (반포동, 반포동 반포상가)     의원  20210226
# 4                    서울특별시 도봉구 방학로 31-16, 신일빌딩 3층 (방학동)     의원      None
# ...                                                 ...    ...       ...
# 8289        경기도 화성시 동탄신리천로 254, 양지프라자 401일부호,402호 (오산동)    한의원  20220103
# 8290       경기도 부천시 소사로78번길 38, 풍림아파트 상가 105,106호 (소사본동)    한의원  20220111
# 8291  경기도 군포시 송부로96번길 12, 군포 송정 풍산 리치안 B동 111, 112호 ...    한의원      None
# 8292                                        경기도 구리시 경춘로    한의원      None
# 8293   경기도 수원시 영통구 덕영대로 1478, 망포역 포레 스퀘어 413,414호 (망포동)    한의원      None
#
#       crtrYm estbCnclTp    estbDd shwSbjtCdNm          telno       yadmNm  \
# ...

# %%
from pyspark.sql import SparkSession

spark = SparkS
